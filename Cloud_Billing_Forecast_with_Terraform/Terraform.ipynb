# %%
# !./terraform init
# Out:
# Initializing the backend...
#
# Initializing provider plugins...
# - Reusing previous version of hashicorp/google from the dependency lock file
# - Reusing previous version of hashicorp/google-beta from the dependency lock file
# - Using previously-installed hashicorp/google v4.48.0
# - Using previously-installed hashicorp/google-beta v4.49.0
#
# Terraform has been successfully initialized!
#
# You may now begin working with Terraform. Try running "terraform plan" to see
# any changes that are required for your infrastructure. All Terraform commands
# should now work.
#
# If you ever set or change modules or backend configuration for Terraform,
# rerun this command to reinitialize your working directory. If you forget, other
# commands will detect it and remind you to do so if necessary.

# %%
# !./terraform plan -var="REGION=us-central1"
# Out:
# google_cloud_run_v2_job.default: Refreshing state... [id=projects/g-sql-morphic-luminous/locations/us-central1/jobs/cloud-billing-forecasting-wth-v2]
#
# Terraform used the selected providers to generate the following execution plan.
# Resource actions are indicated with the following symbols:
# -/+ destroy and then create replacement
#
# Terraform will perform the following actions:
#
#   # google_cloud_run_v2_job.default must be replaced
# -/+ resource "google_cloud_run_v2_job" "default" {
#       ~ conditions               = [] -> (known after apply)
#       ~ etag                     = "\"CKOYnJ4GEJDU_aMC/cHJvamVjdHMvZy1zcWwtbW9ycGhpYy1sdW1pbm91cy9sb2NhdGlvbnMvdXMtY2VudHJhbDEvam9icy9jbG91ZC1iaWxsaW5nLWZvcmVjYXN0aW5nLXd0aC12Mg\"" -> (known after apply)
#       ~ execution_count          = 1 -> (known after apply)
#       ~ generation               = "1" -> (known after apply)
# ...

# %%
# !./terraform apply -var="REGION=us-central1" \
                -auto-approve
# Out:
# Terraform used the selected providers to generate the following execution plan.
# Resource actions are indicated with the following symbols:
#   + create
#
# Terraform will perform the following actions:
#
#   # google_cloud_run_v2_job.default will be created
#   + resource "google_cloud_run_v2_job" "default" {
#       + conditions               = (known after apply)
#       + etag                     = (known after apply)
#       + execution_count          = (known after apply)
#       + generation               = (known after apply)
#       + id                       = (known after apply)
#       + latest_created_execution = (known after apply)
#       + launch_stage             = "BETA"
#       + location                 = "us-central1"
#       + name                     = "cloud-billing-forecasting-bfyex"
#       + observed_generation      = (known after apply)
#       + project                  = "g-sql-morphic-luminous"
#       + reconciling              = (known after apply)
# ...
